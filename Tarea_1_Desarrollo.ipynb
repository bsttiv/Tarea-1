# %% [markdown]
# <a href="https://colab.research.google.com/github/bsttiv/Tarea-1/blob/main/Tarea_1_Desarrollo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CD2201-16: Ciencia de Datos en Astronomía**
#
# **Profesores:** Boris Cuevas, Paula Díaz, Danilo Sepúlveda, Francisco Urbina
# # **Tarea 1: Introducción a Numpy, Pandas y Matplotlib**
#
# El objetivo de esta tarea es repasar y aprender contenidos básicos de estas librerías que les serán útiles para el resto del curso.
#
# Recordar las instrucciones mencionadas en clases:
# 1. Para hacer esta tarea tienen que hacer un fork del repositorio en sus
# cuentas de GitHub.
# 2. Luego deben habilitar sus cuentas de Google Colab (cuenta Google requerida)
# 3. Abrir Google Colab y seleccionar "abrir un archivo desde GitHub". Deben seleccionar su cuenta Github y escoger el repositorio que corresponde al fork que hicieron.
# 4. Si todo sale bien, debería abrirse una copia de este notebook en su cuenta de Google Colab.
# 5. Cada vez que completen un ítem, deben guardar un avance en su fork de GitHub, de modo de respaldar cada avance significativo. Usen comentarios coherentes con cada respaldo "Sección de Numpy completada", "Tarea terminada", no solamente el que pone por defecto.

# %%
# Antes de comenzar con la tarea debe correr esta celda para importar las librerías principales a utilizar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Numpy (Tiempo estimado: 15 min)
#
# Una de las características principales que vuelven a Numpy tan útil son sus capacidades algebráicas, y la posibilidad de trabajar con conjuntos de datos de N dimensiones, lo que permite acelerar cálculos. Para destacar esto, a continuación se hacen una serie de ejercicios simples donde se pide que realicen las mismas operaciones usando Numpy y las listas de Python, y que luego comparen cuánto tarda cada operación.
#
# Para visualizar la velocidad de Numpy respecto a las listas de Python, deberán correr las funciones que se les pide a continuación con $\textit{%timeit}$, de la siguiente manera:
#
# ```
# %timeit nombre_funcion(parametro_1, parametro_2)
# ```
#
# Esto entregará como output el tiempo medio que toma en correr la función y la desviación estándar

# %% [markdown]
# ### Crear arreglos y listas
# A continuación debes crear un par de listas de Python y un par de arreglos de Numpy. Estos arreglos son los que se utilizarán para testear las funciones que crearás en las celdas siguientes.
#
# La primera lista debe ser una secuencia de números enteros desde 1 hasta 49. La segunda debe ir desde 101 hasta 149. Lo mismo para los arreglos.

# %%
# Cree las listas aquí
a_list = list(range(1, 50))
b_list = list(range(101, 150))

# Cree los arreglos aquí
a_arr = np.arange(1, 50, 1)
b_arr = np.arange(101, 150, 1)

# %% [markdown]
# ### Suma de listas de elementos
#
# * Cree la función $\textbf{suma_listas}$, que sume 2 listas de python $a$ y $b$.
# * Cree la función $\textbf{suma_arrays}$, que sume 2 arrays de numpy $a$ y $b$.
# * Compare la eficiencia de las 2 funciones utilizando $\textit{%timeit}$ para cada una

# %%
# Cree las funciones aquí

def suma_listas(lista_1, lista_2):
  return list(map(lambda elementos: elementos[0] + elementos[1], zip(lista_1, lista_2)))

def suma_arrays(lista_1:np.array, lista_2:np.array) -> np.array:
  return lista_1 + lista_2

# %%
# Compare el tiempo aquí
print("suma_listas:")
# %timeit -n 100000 suma_listas(a_list, b_list)
print("suma_arrays")
# %timeit -n 100000 suma_arrays(a_arr, b_arr)

# suma_arrays es aproximadamente 10 veces más rápido
# Out:
# suma_listas:
# 7.45 µs ± 171 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# suma_arrays
# 717 ns ± 48.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ### Multiplicación de listas de elementos
#
# * Cree la función $\textbf{mupliply_listas}$, que multiplique 2 listas de python $a$ y $b$
# * Cree la función $\textbf{mupliply_arrays}$, que multiplique 2 listas de python $a$ y $b$
# * Compare la eficiencia de las 2 funciones utilizando $\textit{%timeit}$ para cada una

# %%
# Cree las funciones aquí

def multiply_listas(lista_1, lista_2):
  return list(map(lambda elementos: elementos[0] * elementos[1], zip(lista_1, lista_2)))

def multiply_arrays(lista_1:np.array, lista_2:np.array) -> np.array:
  return lista_1 * lista_2

# %%
# Compare el tiempo aquí

print("multiply_listas:")
# %timeit -n 100000 multiply_listas(a_list, b_list)
print("multiply_arrays")
# %timeit -n 100000 multiply_arrays(a_arr, b_arr)

# Nuevamente, la version con arrays es aproximadamente 10 veces más rápida
# Out:
# multiply_listas:
# 10.9 µs ± 3.08 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# multiply_arrays
# 781 ns ± 25.6 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ### Aplicación práctica (IMF de Salpeter)
#
# Las Funciones de Masa Inicial (IMF) son muy útil es astronomía pues nos da cuenta de un estimado del número de estrellas que se van a formar en un periodo de formación estelar a partir de un reservorio de masa M [referencia](https://es.wikipedia.org/wiki/Función_de_masa_inicial), lo que permite estudiar poblaciones estelares. En particular, si tenemos un rango de masas $[M_1, M_2]$, se puede demostrar que el número de estrellas que nacerán de un reservorio de masa $\xi_0$ (ignorar unidades) está dada por ecuación $(1)$
#
# $$N = \frac{\xi_0}{1.35} (M_1^{-1.35} - M_2^{-1.35}) \tag{1}$$
#
# Para esta prueba usted debe:
#
# * Crear un array de masas $\textbf{lista_masas}$ que vaya desde $0.2 M_{\odot}$ hasta $80 M_{\odot}$, con pasos de $0.05 M_{\odot}$. Note que para este ejercicio puede ignorar la unidad de la masa.
# * Recrear la ecuación $(1)$ como función en python. Considere $\xi_0=1$
# * Calcular el número de estrellas que se formarán por intervalo de $\textbf{lista_masas}$, en $[0.2, 0.25], [0.25, 0.3], [0.3, 0.35], ..., [79.9, 79.95] y [79.95, 80]$ utilizando Numpy.
# * Luego calcule el número total de estrellas formadas, es decir, sume todos los números de estrellas calculados en el punto anterior.

# %%
# Cree el arreglo

lista_masas = np.arange(0.2, 80.05, 0.05)

# %%
# Cree la función que se le pide
def IMF(m1, m2):
  return (m1**(-1.35) - m2**(-1.35))/1.35

# %%
# Haga los cálculos aquí
it = np.nditer(lista_masas, flags = ['f_index'])
last_index = 0
estrellas = np.zeros(lista_masas.size)
while not (it.finished or last_index == lista_masas.size-2):
  last_index = it.index
  next_index = it.index + 1
  masa1 = lista_masas[last_index]
  masa2 = lista_masas[next_index]
  numero_estrellas = IMF(masa1, masa2)
  estrellas = np.insert(estrellas, last_index, [numero_estrellas])
  print(f"Numero de estrellas para el intervalo [{masa1}, {masa2}]: {numero_estrellas}")
  it.iternext()
print("Total de estrellas: ", estrellas.sum())
# Out:
# Numero de estrellas para el intervalo [0.2, 0.25]: 1.692078410281669
# Numero de estrellas para el intervalo [0.25, 0.3]: 1.050188800583046
# Numero de estrellas para el intervalo [0.3, 0.35]: 0.707010806202053
# Numero de estrellas para el intervalo [0.35, 0.39999999999999997]: 0.5041210542281656
# Numero de estrellas para el intervalo [0.39999999999999997, 0.44999999999999996]: 0.3751726939943242
# Numero de estrellas para el intervalo [0.44999999999999996, 0.49999999999999994]: 0.28861621255638137
# Numero de estrellas para el intervalo [0.49999999999999994, 0.5499999999999999]: 0.2279760704474408
# Numero de estrellas para el intervalo [0.5499999999999999, 0.5999999999999999]: 0.18400464591591909
# Numero de estrellas para el intervalo [0.5999999999999999, 0.6499999999999999]: 0.1512044015735442
# Numero de estrellas para el intervalo [0.6499999999999999, 0.7]: 0.12615031622010212
# Numero de estrellas para el intervalo [0.7, 0.7499999999999998]: 0.10662367842757371
# Numero de estrellas para el intervalo [0.7499999999999998, 0.7999999999999998]: 0.09113900285360829
# Numero de estrellas para el intervalo [0.7999999999999998, 0.8499999999999999]: 0.07867318449088731
# Numero de estrellas para el intervalo [0.8499999999999999, 0.8999999999999999]: 0.06850408034562819
# Numero de estrellas para el intervalo [0.8999999999999999, 0.9499999999999997]: 0.060110913137966605
# Numero de estrellas para el intervalo [0.9499999999999997, 0.9999999999999998]: 0.05311093224549602
# Numero de estrellas para el intervalo [0.9999999999999998, 1.0499999999999998]: 0.04721804547912744
# Numero de estrellas para el intervalo [1.0499999999999998, 1.0999999999999999]: 0.04221515430789832
# Numero de estrellas para el intervalo [1.0999999999999999, 1.1499999999999997]: 0.03793525825091889
# Numero de estrellas para el intervalo [1.1499999999999997, 1.1999999999999997]: 0.03424830131145728
# Numero de estrellas para el intervalo [1.1999999999999997, 1.2499999999999998]: 0.031051856935801377
# Numero de estrellas para el intervalo [1.2499999999999998, 1.2999999999999996]: 0.02826442756749711
# Numero de estrellas para el intervalo [1.2999999999999996, 1.3499999999999996]: 0.025820555769933713
# Numero de estrellas para el intervalo [1.3499999999999996, 1.3999999999999997]: 0.02366721025553567
# Numero de estrellas para el intervalo [1.3999999999999997, 1.4499999999999997]: 0.021761082075742146
# Numero de estrellas para el intervalo [1.4499999999999997, 1.4999999999999998]: 0.020066539201023564
# Numero de estrellas para el intervalo [1.4999999999999998, 1.5499999999999996]: 0.0185540632033989
# Numero de estrellas para el intervalo [1.5499999999999996, 1.5999999999999996]: 0.017199042965154895
# Numero de estrellas para el intervalo [1.5999999999999996, 1.6499999999999997]: 0.015980835577474584
# Numero de estrellas para el intervalo [1.6499999999999997, 1.6999999999999995]: 0.014882029163749082
# Numero de estrellas para el intervalo [1.6999999999999995, 1.7499999999999996]: 0.013887859705826238
# Numero de estrellas para el intervalo [1.7499999999999996, 1.7999999999999996]: 0.01298574633428434
# Numero de estrellas para el intervalo [1.7999999999999996, 1.8499999999999996]: 0.012164918480074652
# Numero de estrellas para el intervalo [1.8499999999999996, 1.8999999999999997]: 0.011416114798976187
# Numero de estrellas para el intervalo [1.8999999999999997, 1.9499999999999995]: 0.010731338573819759
# Numero de estrellas para el intervalo [1.9499999999999995, 1.9999999999999996]: 0.010103657858324183
# Numero de estrellas para el intervalo [1.9999999999999996, 2.05]: 0.009527041290889963
# Numero de estrellas para el intervalo [2.05, 2.0999999999999996]: 0.008996222517454506
# Numero de estrellas para el intervalo [2.0999999999999996, 2.1499999999999995]: 0.008506587691345687
# Numero de estrellas para el intervalo [2.1499999999999995, 2.1999999999999997]: 0.008054081688771563
# Numero de estrellas para el intervalo [2.1999999999999997, 2.2499999999999996]: 0.0076351295811210515
# Numero de estrellas para el intervalo [2.2499999999999996, 2.3]: 0.007246570605517785
# Numero de estrellas para el intervalo [2.3, 2.3499999999999996]: 0.006885602421726385
# Numero de estrellas para el intervalo [2.3499999999999996, 2.3999999999999995]: 0.006549733872746455
# Numero de estrellas para el intervalo [2.3999999999999995, 2.4499999999999997]: 0.0062367448053299605
# Numero de estrellas para el intervalo [2.4499999999999997, 2.4999999999999996]: 0.005944651775667378
# Numero de estrellas para el intervalo [2.4999999999999996, 2.55]: 0.005671678680094401
# Numero de estrellas para el intervalo [2.55, 2.5999999999999996]: 0.005416231522712052
# Numero de estrellas para el intervalo [2.5999999999999996, 2.6499999999999995]: 0.005176876670375581
# Numero de estrellas para el intervalo [2.6499999999999995, 2.6999999999999997]: 0.004952322057597505
# Numero de estrellas para el intervalo [2.6999999999999997, 2.7499999999999996]: 0.0047414008949765146
# Numero de estrellas para el intervalo [2.7499999999999996, 2.8]: 0.004543057509059552
# Numero de estrellas para el intervalo [2.8, 2.8499999999999996]: 0.004356335002380208
# Numero de estrellas para el intervalo [2.8499999999999996, 2.8999999999999995]: 0.004180364472446407
# Numero de estrellas para el intervalo [2.8999999999999995, 2.9499999999999997]: 0.004014355569713305
# Numero de estrellas para el intervalo [2.9499999999999997, 2.9999999999999996]: 0.0038575882087591193
# Numero de estrellas para el intervalo [2.9999999999999996, 3.0499999999999994]: 0.003709405275270083
# Numero de estrellas para el intervalo [3.0499999999999994, 3.0999999999999996]: 0.0035692061951089656
# Numero de estrellas para el intervalo [3.0999999999999996, 3.1499999999999995]: 0.0034364412515322617
# Numero de estrellas para el intervalo [3.1499999999999995, 3.1999999999999993]: 0.0033106065532194514
# Numero de estrellas para el intervalo [3.1999999999999993, 3.2499999999999996]: 0.0031912395697386575
# Numero de estrellas para el intervalo [3.2499999999999996, 3.2999999999999994]: 0.0030779151628559415
# Numero de estrellas para el intervalo [3.2999999999999994, 3.3499999999999996]: 0.0029702420520566278
# Numero de estrellas para el intervalo [3.3499999999999996, 3.3999999999999995]: 0.002867859661099999
# Numero de estrellas para el intervalo [3.3999999999999995, 3.4499999999999993]: 0.0027704352996174675
# Numero de estrellas para el intervalo [3.4499999999999993, 3.4999999999999996]: 0.002677661639888683
# Numero de estrellas para el intervalo [3.4999999999999996, 3.5499999999999994]: 0.00258925445416965
# Numero de estrellas para el intervalo [3.5499999999999994, 3.5999999999999996]: 0.0025049505824306134
# Numero de estrellas para el intervalo [3.5999999999999996, 3.6499999999999995]: 0.002424506104212434
# Numero de estrellas para el intervalo [3.6499999999999995, 3.6999999999999993]: 0.0023476946916259856
# Numero de estrellas para el intervalo [3.6999999999999993, 3.7499999999999996]: 0.002274306123374006
# Numero de estrellas para el intervalo [3.7499999999999996, 3.7999999999999994]: 0.00220414494214624
# Numero de estrellas para el intervalo [3.7999999999999994, 3.849999999999999]: 0.002137029239876773
# Numero de estrellas para el intervalo [3.849999999999999, 3.8999999999999995]: 0.0020727895572057063
# Numero de estrellas para el intervalo [3.8999999999999995, 3.9499999999999993]: 0.002011267885102756
# Numero de estrellas para el intervalo [3.9499999999999993, 3.999999999999999]: 0.0019523167580125797
# Numero de estrellas para el intervalo [3.999999999999999, 4.049999999999999]: 0.0018957984291084133
# Numero de estrellas para el intervalo [4.049999999999999, 4.099999999999999]: 0.0018415841193105522
# Numero de estrellas para el intervalo [4.099999999999999, 4.1499999999999995]: 0.0017895533326655136
# Numero de estrellas para el intervalo [4.1499999999999995, 4.199999999999999]: 0.0017395932315022599
# Numero de estrellas para el intervalo [4.199999999999999, 4.249999999999999]: 0.001691598065506935
# Numero de estrellas para el intervalo [4.249999999999999, 4.299999999999999]: 0.0016454686494901155
# Numero de estrellas para el intervalo [4.299999999999999, 4.35]: 0.0016011118851843112
# Numero de estrellas para el intervalo [4.35, 4.3999999999999995]: 0.0015584403229014754
# Numero de estrellas para el intervalo [4.3999999999999995, 4.449999999999999]: 0.0015173717593185707
# Numero de estrellas para el intervalo [4.449999999999999, 4.499999999999999]: 0.001477828868045738
# Numero de estrellas para el intervalo [4.499999999999999, 4.549999999999999]: 0.0014397388599751086
# Numero de estrellas para el intervalo [4.549999999999999, 4.599999999999999]: 0.0014030331707125202
# Numero de estrellas para el intervalo [4.599999999999999, 4.6499999999999995]: 0.0013676471726649837
# Numero de estrellas para el intervalo [4.6499999999999995, 4.699999999999999]: 0.0013335199095979844
# Numero de estrellas para el intervalo [4.699999999999999, 4.749999999999999]: 0.0013005938516915199
# Numero de estrellas para el intervalo [4.749999999999999, 4.799999999999999]: 0.0012688146693147545
# Numero de estrellas para el intervalo [4.799999999999999, 4.849999999999999]: 0.001238131023911289
# Numero de estrellas para el intervalo [4.849999999999999, 4.8999999999999995]: 0.0012084943745397328
# Numero de estrellas para el intervalo [4.8999999999999995, 4.949999999999999]: 0.0011798587987513105
# Numero de estrellas para el intervalo [4.949999999999999, 4.999999999999999]: 0.001152180826609843
# Numero de estrellas para el intervalo [4.999999999999999, 5.049999999999999]: 0.0011254192867689973
# Numero de estrellas para el intervalo [5.049999999999999, 5.099999999999999]: 0.001099535163622041
# Numero de estrellas para el intervalo [5.099999999999999, 5.1499999999999995]: 0.0010744914646276084
# Numero de estrellas para el intervalo [5.1499999999999995, 5.199999999999999]: 0.0010502530969958936
# Numero de estrellas para el intervalo [5.199999999999999, 5.249999999999999]: 0.0010267867529925795
# Numero de estrellas para el intervalo [5.249999999999999, 5.299999999999999]: 0.0010040608031821135
# Numero de estrellas para el intervalo [5.299999999999999, 5.349999999999999]: 0.0009820451969922695
# Numero de estrellas para el intervalo [5.349999999999999, 5.3999999999999995]: 0.0009607113700348781
# Numero de estrellas para el intervalo [5.3999999999999995, 5.449999999999999]: 0.0009400321576655679
# Numero de estrellas para el intervalo [5.449999999999999, 5.499999999999999]: 0.0009199817143104377
# Numero de estrellas para el intervalo [5.499999999999999, 5.549999999999999]: 0.0009005354381256229
# Numero de estrellas para el intervalo [5.549999999999999, 5.599999999999999]: 0.000881669900593633
# Numero de estrellas para el intervalo [5.599999999999999, 5.649999999999999]: 0.0008633627806916092
# Numero de estrellas para el intervalo [5.649999999999999, 5.699999999999999]: 0.0008455928032976607
# Numero de estrellas para el intervalo [5.699999999999999, 5.749999999999999]: 0.0008283396815275062
# Numero de estrellas para el intervalo [5.749999999999999, 5.799999999999999]: 0.000811584062719491
# Numero de estrellas para el intervalo [5.799999999999999, 5.849999999999999]: 0.0007953074778074728
# Numero de estrellas para el intervalo [5.849999999999999, 5.899999999999999]: 0.0007794922938426671
# Numero de estrellas para el intervalo [5.899999999999999, 5.949999999999999]: 0.000764121669443431
# Numero de estrellas para el intervalo [5.949999999999999, 5.999999999999999]: 0.0007491795129697993
# Numero de estrellas para el intervalo [5.999999999999999, 6.049999999999999]: 0.0007346504432350363
# Numero de estrellas para el intervalo [6.049999999999999, 6.099999999999999]: 0.0007205197525805737
# Numero de estrellas para el intervalo [6.099999999999999, 6.149999999999999]: 0.0007067733721543197
# Numero de estrellas para el intervalo [6.149999999999999, 6.199999999999998]: 0.0006933978392441874
# Numero de estrellas para el intervalo [6.199999999999998, 6.249999999999999]: 0.000680380266529717
# Numero de estrellas para el intervalo [6.249999999999999, 6.299999999999999]: 0.000667708313124612
# Numero de estrellas para el intervalo [6.299999999999999, 6.349999999999999]: 0.0006553701572932245
# Numero de estrellas para el intervalo [6.349999999999999, 6.399999999999999]: 0.0006433544707311488
# Numero de estrellas para el intervalo [6.399999999999999, 6.449999999999998]: 0.0006316503943094698
# Numero de estrellas para el intervalo [6.449999999999998, 6.499999999999999]: 0.0006202475151884409
# Numero de estrellas para el intervalo [6.499999999999999, 6.549999999999999]: 0.0006091358452134582
# Numero de estrellas para el intervalo [6.549999999999999, 6.599999999999999]: 0.0005983058005125745
# Numero de estrellas para el intervalo [6.599999999999999, 6.649999999999999]: 0.000587748182219728
# Numero de estrellas para el intervalo [6.649999999999999, 6.699999999999998]: 0.0005774541582541832
# Numero de estrellas para el intervalo [6.699999999999998, 6.749999999999999]: 0.0005674152460905483
# Numero de estrellas para el intervalo [6.749999999999999, 6.799999999999999]: 0.0005576232964587781
# Numero de estrellas para el intervalo [6.799999999999999, 6.849999999999999]: 0.0005480704779175443
# Numero de estrellas para el intervalo [6.849999999999999, 6.899999999999999]: 0.0005387492622482939
# Numero de estrellas para el intervalo [6.899999999999999, 6.949999999999998]: 0.0005296524106203913
# Numero de estrellas para el intervalo [21.949999999999996, 21.999999999999993]: 3.511056878725261e-05
# Numero de estrellas para el intervalo [21.999999999999993, 22.049999999999994]: 3.4923545961576076e-05
# Numero de estrellas para el intervalo [22.049999999999994, 22.099999999999994]: 3.473794005466936e-05
# Numero de estrellas para el intervalo [22.099999999999994, 22.149999999999995]: 3.45537371587275e-05
# Numero de estrellas para el intervalo [22.149999999999995, 22.199999999999996]: 3.437092353346459e-05
# Numero de estrellas para el intervalo [22.199999999999996, 22.249999999999993]: 3.41894856037147e-05
# Numero de estrellas para el intervalo [22.249999999999993, 22.299999999999994]: 3.4009409957098324e-05
# Numero de estrellas para el intervalo [22.299999999999994, 22.349999999999994]: 3.383068334169277e-05
# Numero de estrellas para el intervalo [22.349999999999994, 22.399999999999995]: 3.365329266377053e-05
# Numero de estrellas para el intervalo [22.399999999999995, 22.449999999999996]: 3.3477224985562195e-05
# Numero de estrellas para el intervalo [22.449999999999996, 22.499999999999993]: 3.3302467523046224e-05
# Numero de estrellas para el intervalo [22.499999999999993, 22.549999999999994]: 3.312900764381079e-05
# Numero de estrellas para el intervalo [22.549999999999994, 22.599999999999994]: 3.295683286488214e-05
# Numero de estrellas para el intervalo [22.599999999999994, 22.649999999999995]: 3.278593085067374e-05
# Numero de estrellas para el intervalo [22.649999999999995, 22.699999999999996]: 3.2616289410902105e-05
# Numero de estrellas para el intervalo [22.699999999999996, 22.749999999999993]: 3.244789649855903e-05
# Numero de estrellas para el intervalo [22.749999999999993, 22.799999999999994]: 3.228074020793662e-05
# Numero de estrellas para el intervalo [22.799999999999994, 22.849999999999994]: 3.2114808772634264e-05
# Numero de estrellas para el intervalo [22.849999999999994, 22.899999999999995]: 3.1950090563656865e-05
# Numero de estrellas para el intervalo [22.899999999999995, 22.949999999999996]: 3.178657408749766e-05
# Numero de estrellas para el intervalo [22.949999999999996, 22.999999999999993]: 3.162424798427242e-05
# Numero de estrellas para el intervalo [22.999999999999993, 23.049999999999994]: 3.1463101025888366e-05
# Numero de estrellas para el intervalo [23.049999999999994, 23.099999999999994]: 3.1303122114213044e-05
# Numero de estrellas para el intervalo [23.099999999999994, 23.149999999999995]: 3.114430027931394e-05
# Numero de estrellas para el intervalo [23.149999999999995, 23.199999999999996]: 3.0986624677695453e-05
# Numero de estrellas para el intervalo [23.199999999999996, 23.249999999999993]: 3.083008459056804e-05
# Numero de estrellas para el intervalo [23.249999999999993, 23.299999999999994]: 3.06746694221649e-05
# Numero de estrellas para el intervalo [23.299999999999994, 23.349999999999994]: 3.0520368698048355e-05
# Numero de estrellas para el intervalo [23.349999999999994, 23.399999999999995]: 3.036717206348308e-05
# Numero de estrellas para el intervalo [23.399999999999995, 23.449999999999996]: 3.0215069281805446e-05
# Numero de estrellas para el intervalo [23.449999999999996, 23.499999999999993]: 3.0064050232832724e-05
# Numero de estrellas para el intervalo [23.499999999999993, 23.549999999999994]: 2.991410491129798e-05
# Numero de estrellas para el intervalo [23.549999999999994, 23.599999999999994]: 2.976522342529011e-05
# Numero de estrellas para el intervalo [23.599999999999994, 23.649999999999995]: 2.9617395994745266e-05
# Numero de estrellas para el intervalo [23.649999999999995, 23.699999999999996]: 2.9470612949948573e-05
# Numero de estrellas para el intervalo [23.699999999999996, 23.749999999999993]: 2.9324864730052547e-05
# Numero de estrellas para el intervalo [23.749999999999993, 23.799999999999994]: 2.9180141881635345e-05
# Numero de estrellas para el intervalo [23.799999999999994, 23.849999999999994]: 2.9036435057256454e-05
# Numero de estrellas para el intervalo [23.849999999999994, 23.899999999999995]: 2.889373501406247e-05
# Numero de estrellas para el intervalo [23.899999999999995, 23.949999999999996]: 2.8752032612398064e-05
# ...
# Numero de estrellas para el intervalo [72.09999999999998, 72.14999999999999]: 2.1501481327191997e-06
# Numero de estrellas para el intervalo [72.14999999999999, 72.19999999999999]: 2.1466493546100797e-06
# Numero de estrellas para el intervalo [72.19999999999999, 72.24999999999999]: 2.143158686872902e-06
# Numero de estrellas para el intervalo [72.24999999999999, 72.29999999999998]: 2.13967610511135e-06
# Numero de estrellas para el intervalo [72.29999999999998, 72.34999999999998]: 2.1362015850209854e-06
# Numero de estrellas para el intervalo [72.34999999999998, 72.39999999999999]: 2.1327351023857096e-06
# Numero de estrellas para el intervalo [72.39999999999999, 72.44999999999999]: 2.129276633078732e-06
# Numero de estrellas para el intervalo [72.44999999999999, 72.49999999999999]: 2.125826153064174e-06
# Numero de estrellas para el intervalo [72.49999999999999, 72.54999999999998]: 2.1223836383932147e-06
# Numero de estrellas para el intervalo [72.54999999999998, 72.59999999999998]: 2.1189490652056953e-06
# Numero de estrellas para el intervalo [72.59999999999998, 72.64999999999999]: 2.1155224097291588e-06
# Numero de estrellas para el intervalo [72.64999999999999, 72.69999999999999]: 2.1121036482775623e-06
# Numero de estrellas para el intervalo [72.69999999999999, 72.74999999999999]: 2.10869275725449e-06
# Numero de estrellas para el intervalo [72.74999999999999, 72.79999999999998]: 2.1052897131486567e-06
# Numero de estrellas para el intervalo [72.79999999999998, 72.84999999999998]: 2.1018944925348705e-06
# Numero de estrellas para el intervalo [72.84999999999998, 72.89999999999999]: 2.098507072074676e-06
# Numero de estrellas para el intervalo [72.89999999999999, 72.94999999999999]: 2.0951274285134617e-06
# Numero de estrellas para el intervalo [72.94999999999999, 72.99999999999999]: 2.0917555386839968e-06
# Numero de estrellas para el intervalo [72.99999999999999, 73.04999999999998]: 2.0883913795035356e-06
# Numero de estrellas para el intervalo [73.04999999999998, 73.09999999999998]: 2.0850349279725367e-06
# Numero de estrellas para el intervalo [73.09999999999998, 73.14999999999999]: 2.0816861611769088e-06
# Numero de estrellas para el intervalo [73.14999999999999, 73.19999999999999]: 2.0783450562841576e-06
# Numero de estrellas para el intervalo [73.19999999999999, 73.24999999999999]: 2.0750115905482035e-06
# Numero de estrellas para el intervalo [73.24999999999999, 73.29999999999998]: 2.0716857413035985e-06
# Numero de estrellas para el intervalo [73.29999999999998, 73.34999999999998]: 2.0683674859687415e-06
# Numero de estrellas para el intervalo [73.34999999999998, 73.39999999999999]: 2.0650568020445892e-06
# Numero de estrellas para el intervalo [79.89999999999999, 79.94999999999999]: 1.6891407702261071e-06
# Numero de estrellas para el intervalo [79.94999999999999, 79.99999999999999]: 1.6866601161360428e-06
# Total de estrellas:  6.5034284076279105

# %% [markdown]
# ## 2. Pandas (Tiempo estimado 20 min)
#
# Para esta sección veremos algunas de las funciones principales que existen dentro de pandas, dando una pincelada a sus capacidades. Como recomendación, puede explorar la [documentación](lista_masas), y mirar el tutorial [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html), pero no es obligatorio para esta parte.

# %% [markdown]
# ### Creación de datos
#
# Recree el siguiente DataFrame **almacen**:
#
#
# |        | Manzana | Frutilla | Melón |
# |--------|---------|----------|-------|
# | Stock inicial  | 25      | 80       | 15    |
# | Ventas | 14      | 60       | 6     |

# %%
datos = {"Manzana": {"Stock inicial": 25, "Ventas": 14},
         "Frutilla": {"Stock inicial": 80, "Ventas": 60},
         "Melón": {"Stock inicial": 15, "Ventas": 6}}
almacen = pd.DataFrame(datos)
almacen
# Out:
#                Manzana  Frutilla  Melón
# Stock inicial       25        80     15
# Ventas              14        60      6

# %% [markdown]
# Haga ahora un inventario de la cantidad que queda por producto después de las ventas, y añada la fila **bodega** con esta información.

# %%
for items in datos.items():
  restante = items[1]["Stock inicial"] - items[1]["Ventas"]
  datos[items[0]]["Bodega"] = restante
almacen = pd.DataFrame(datos)
almacen
# Out:
#                Manzana  Frutilla  Melón
# Stock inicial       25        80     15
# Ventas              14        60      6
# Bodega              11        20      9

# %% [markdown]
# ### Visualización de Tablas
# Para esta parte primero debe montar el drive, lo que permite leer archivos guardados en el mismo. Para esto debe correr la celda de abajo.

# %%
from google.colab import drive
drive.mount('/content/drive')    # se le debe abrir una pestaña extra pidiendo permisos
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importe el dataset (archivo **censo.csv**) utilizando la función **pd.load_csv(path)** y guárdelo como **df_censo**.
#
# En la barra de herramientas ubicada en la izquierda, puede encontrar la ruta (path) al archivo "censo.csv" dentro de su drive. Copie la ruta y cargue dicha base de datos en la siguiente celda como se le indica.

# %%
path = 'drive/MyDrive/Modulo/Tarea1/censo.csv'
df_censo = pd.read_csv(path)

# %% [markdown]
# Con este dataset se pide hacer lo siguiente:
#
# * Vea los primeros 10 elementos de $\textbf{df_censo}$
# * Vea las columnas del dataframe
# * Traduzca las columnas a español (manualmente).
# * Use la función $\textbf{describe}$ para visualizar la estadística de cada columna del dataframe. ¿Ve algo que no tiene sentido?

# %%
# Agregue más celdas si es necesario
df_censo[0:10]
# Out:
#                                name        city  age  n_siblings
# 0      Paula_Miguel_Garcia_Gonzalez     Iquique   35           0
# 1         Maria_Pedro_Jimenez_Lopez    Rancagua   49          -1
# 2    Carolina_Juan_Jimenez_Gonzalez     Iquique   16           1
# 3          Lucia_Marta_Jimenez_Sanz    Santiago   42           2
# 4         Marta_Roberto_Garcia_Sanz  Valparaiso   12           3
# 5         Roberto_Paula_Lopez_Gomez       Arica   38          -2
# 6  Pedro_Valentina_Garcia_Hernandez    Santiago   40           0
# 7         Sofia_Marta_Garcia_Garcia    Santiago   10           1
# 8   Carolina_Eduardo_Perez_Gonzalez    Santiago   40           0
# 9     Pedro_Julia_Gonzalez_Gonzalez    Santiago   55           0

# %%
df_censo = df_censo.rename(index=int, columns={"name": "nombre", "city": "ciudad", "age": "edad", "n_siblings": "n_hermanos"})
df_censo.describe()
# Out:
#               edad  n_hermanos
# count  2000.000000  2000.00000
# mean     34.286500     0.75000
# std      14.724158     1.73234
# min     -26.000000    -6.00000
# 25%      24.000000     0.00000
# 50%      34.000000     0.00000
# 75%      44.000000     2.00000
# max      84.000000     7.00000

# %% [markdown]
# Hay algunos datos que no tienen sentido. Por ejemplo, el mínimo de edad es -26 y el de n_hermanos es -6, los cuales no deberian ser numeros negativos. Además, el promedio de hermanos es 0.75, lo que no es posible pues no pueden haber 0.75 personas.

# %% [markdown]
# ### Filtar los datos
#
# Repare el dataframe siguiendo los siguientes pasos:
#
# * Descarte los elementos del dataframe donde la edad sea menor a cero.
# * Reemplace los casos en que el número de hermanos es menor a cero por cero.
# * Descarte los casos en que el mismo nombre aparezca más de una vez (use la función [drop_duplicates](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html#pandas.DataFrame.drop_duplicates) y mantenga el primer elemento: keep = 'first').

# %%
# Agregue más celdas si es necesario
df_censo.query("edad > 0", inplace=True)
df_censo.drop_duplicates(subset=["nombre"], keep='first')
df_censo.loc[df_censo["n_hermanos"] < 0, "n_hermanos"] = 0
df_censo.describe()
# Out:
#               edad   n_hermanos
# count  1980.000000  1980.000000
# mean     34.701010     1.039394
# std      14.183469     1.364927
# min       1.000000     0.000000
# 25%      24.000000     0.000000
# 50%      34.000000     0.000000
# 75%      44.000000     2.000000
# max      84.000000     7.000000

# %% [markdown]
# ## 3. Matplotlib
#
# Matplotlib es la librería que nos permitirá crear todo tipo de figuras para visualizar nuestros datos ([documentación](https://matplotlib.org/stable/index.html)). A pesar de su popularidad, no posee una gran versatilidad al momento de hacer una visulización interactiva. Sin embargo,su fiabilidad y simplicidad la han hecho una de las librerías fundamentales para la ciencia de datos en Python.

# %% [markdown]
# ### Visualización simple

# %% [markdown]
# Genere un arreglo de 100 números que vayan desde 0 a 4$\pi$.

# %%
x_values = np.linspace(0, 4*np.pi, 100)

# %% [markdown]
# Utilizando las funciones **np.sin()** y **np.cos()** de numpy, cree la siguiente función:
# $$f(x) = 1.5[\sin(3x+\pi/4)+\cos(2x)] \tag{2}$$
#
# Luego aplique la función al arreglo generado en la celda de arriba y grafique. Haga el plot sin crear una figura, es decir solo usando el comando **plt.plot(x, y)**.

# %%
# Escriba la función aquí
def f(x):
  return 1.5*(np.sin(3*x + np.pi/4) + np.cos(2*x))

# Haga el plot aquí
y_values = list(map(f, x_values))
plt.plot(x_values, y_values)

# %% [markdown]
# Ahora incluya también en el plot la misma función  pero con un poco de ruido. Para esto simplemente debes sumar la variable **ruido** definida abajo a la función.
#
# Plotee la función ruidosa de color rojo, y en azul la función sin ruido. Incluya además una leyenda con **plt.legend()**. Ojo que para que aparezca la leyenda de la figura, en **plt.plot()** debe incluir el parámetro **label**

# %%
np.random.seed(19680801) # por ahora ignorar esto
ruido = 0.4*np.random.randn(len(x_values))
y_values_ruido = y_values + ruido
# Línea para plotear función sin ruido
plt.plot(x_values, y_values, color='blue', label="Función sin ruido")

# Línea para plotear función con ruido
plt.plot(x_values, y_values_ruido, color='red', label="Función con ruido")

plt.legend()

# %% [markdown]
# Es una buena práctica también el siempre inicializar una figura. Esto además permite definir un tamaño al plot que se va a generar. Use **plt.figure(figsize=(size_x, size_y))** para cambiar el tamaño de la figura y recree todo lo que hizo en la celda anterior.

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot()
ax.plot(x_values, y_values, color='blue', label="Función sin ruido")
ax.plot(x_values, y_values_ruido, color='red', label="Función con ruido")
ax.legend()

# %% [markdown]
# Para estas funciones, sabemos que tiene un mayor sentido definir el eje x en función de $\pi$ en lugar de números enteros. Haga de nuevo la figura pero ahora utilize la función **plt.xticks()** para reescribir los valores de x como múltiplos de $\pi$. Utilice como labels la lista **xticks_labels** que ya está definida.
#
# Además, tenga en cuenta que se puede escribir texto en latex de la siguiente forma:
# ```
# r'$\pi$'
# ```

# %%
xticks_labels = [r'$\pi$', r'$2\pi$', r'$3\pi$', r'$4\pi$']
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot()
ax.set_xticks([np.pi, 2*np.pi, 3*np.pi, 4*np.pi], xticks_labels)
ax.plot(x_values, y_values, color='blue', label="Función sin ruido")
ax.plot(x_values, y_values_ruido, color='red', label="Función con ruido")
ax.legend()

# %% [markdown]
# Como ultimo paso, agregue una grilla con **plt.grid(True)**. Además añada un título a la figura y labels en ambos ejes (x e y) que tengan sentido.

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot()
ax.set_xticks([np.pi, 2*np.pi, 3*np.pi, 4*np.pi], xticks_labels)
ax.plot(x_values, y_values, color='blue', label="Función sin ruido")
ax.plot(x_values, y_values_ruido, color='red', label="Función con ruido")
ax.grid(True)
ax.set_title("Función f graficada con y sin ruido desde 0 a 4$\pi$")
ax.set_xlabel("Ángulo")
ax.set_ylabel("Valor de f")
ax.legend()

# %% [markdown]
# ### Visualización distribución de estrellas
#
# El archivo **galaxy2.csv** contiene datos de la posición de estrellas sintéticas de una galaxia. Al igual que en la sección anterior, cargue los datos utilizando **pd.read_csv()**.

# %%
# Carge y abra el archivo
path = 'drive/MyDrive/Modulo/Tarea1/galaxy2.csv'
df_galaxia = pd.read_csv(path)
df_galaxia
# Out:
#                         key          x[m]          y[m]          z[m]  \
# 0       2536799254509432540  9.016510e+17  4.745163e+17  3.009401e+16
# 1      16568176108934293527 -9.545587e+16 -2.795457e+17 -2.217165e+16
# 2        212848180443948653  4.908724e+17 -1.870607e+18  9.142949e+15
# 3        584293945272726282 -8.367689e+17 -2.974291e+17 -4.054180e+15
# 4      15485527814176396751  2.343487e+16  2.799849e+17 -2.554723e+16
# ...                     ...           ...           ...           ...
# 40095   8972477052627890130 -5.257426e+17 -2.160534e+19 -1.687303e+18
# 40096   3695764516254316728  1.963205e+17  1.183779e+18  4.895338e+17
# 40097  17617397667571159511 -4.528748e+18 -4.665755e+18  3.232435e+18
# 40098  16130134547917784508  2.947325e+18 -3.515739e+15  1.659993e+18
# 40099  11941135087396799780 -2.541212e+18  2.372081e+18  1.282449e+18
#
#             vx[m/s]       vy[m/s]       vz[m/s]
# 0     -1.625572e+06  2.845114e+06 -3.486599e+04
# 1      1.855060e+06 -1.920465e+06 -2.893263e+05
# 2      3.380713e+06  7.971010e+05  4.905219e+04
# 3      6.618865e+05 -3.375086e+06  2.686391e+05
# 4     -2.484394e+06 -1.171416e+05 -5.705734e+05
# ...             ...           ...           ...
# 40095 -9.137532e+05 -6.192531e+05 -1.911085e+04
# 40096  5.597525e+05 -4.871850e+06  1.731664e+06
# 40097  2.553710e+06 -2.112712e+06 -2.013541e+06
# 40098  1.339880e+06 -1.200858e+06 -1.979899e+06
# 40099  2.736939e+06  4.692433e+06  1.187456e+06
#
# [40100 rows x 7 columns]

# %% [markdown]
# Vea los primeros 10 elementos del dataframe. ¿Qué tipo de información puede encontrar? Dado el nombre de las columnas, ¿en qué unidades se encuentran?
#
# **Respuesta:** Se pueden encontrar las claves (identificadores) y las posiciones de las estrellas de una galaxia (metros) en un espacio tridimensional, así como sus velocidades en cada eje (en metros/segundos)

# %%
df_galaxia[0:10]
# Out:
#                     key          x[m]          y[m]          z[m]  \
# 0   2536799254509432540  9.016510e+17  4.745163e+17  3.009401e+16
# 1  16568176108934293527 -9.545587e+16 -2.795457e+17 -2.217165e+16
# 2    212848180443948653  4.908724e+17 -1.870607e+18  9.142949e+15
# 3    584293945272726282 -8.367689e+17 -2.974291e+17 -4.054180e+15
# 4  15485527814176396751  2.343487e+16  2.799849e+17 -2.554723e+16
# 5   3355351822461698455 -5.025008e+17 -8.725557e+17 -5.071959e+15
# 6  11306543906972088773 -7.294104e+16  2.996010e+17  2.552034e+16
# 7    783275702291551918  4.886403e+16 -1.366570e+18  4.799806e+14
# 8   2994623897157713080 -1.850651e+17  1.004086e+18 -5.464441e+15
# 9  13439637019970929881  1.918695e+17  1.011757e+17  2.188518e+16
#
#         vx[m/s]       vy[m/s]       vz[m/s]
# 0 -1.625572e+06  2.845114e+06 -3.486599e+04
# 1  1.855060e+06 -1.920465e+06 -2.893263e+05
# 2  3.380713e+06  7.971010e+05  4.905219e+04
# 3  6.618865e+05 -3.375086e+06  2.686391e+05
# 4 -2.484394e+06 -1.171416e+05 -5.705734e+05
# 5  2.700085e+06 -2.203650e+06 -1.303846e+05
# 6 -3.080776e+06 -1.458240e+06  1.005820e+06
# 7  3.573072e+06  3.520636e+04 -2.359365e+03
# 8 -3.330370e+06 -7.812421e+05 -7.749480e+04
# 9 -1.188553e+06  2.041306e+06 -5.645056e+05

# %% [markdown]
# Plotee las estrellas en el plano $[x, y]$ utilizando **plt.plot()**. Para hacer esto hay que plotear solo los marcadores, esto se puede hacer con: **marker=' . ', linestyle='  '**, o simplemente con **' . '**. Recuerde agregar los labels en cada eje.

# %%
plt.plot(df_galaxia["x[m]"], df_galaxia["y[m]"], '.')
plt.xlabel("Posiciones de las estrellas en el eje x [m]")
plt.ylabel("Posiciones de las estrellas en el eje y [m]")
# Out:
# Text(0, 0.5, 'Posiciones de las estrellas en el eje y [m]')

# %% [markdown]
# Se puede ver que muchas de las estrellas se extienden muy lejos de la galaxia. Para simplificar la visualización setee un **plt.xlim()** y **plt.ylim()** en el rago que considere que funcione mejor (Recomendación, como los números son muy grandes, use la notación $1eN$, con $N$ el orden de magnitud, para facilitar la escritura).
#
# Adicionalmente, cuando se trabaja con marcadores, podemos usar el parámetro **markersize** para modificar su tamaño. El plot anterior muestra con bastante claridad las estrellas que están más lejanas, pero dificulta la visualización de las regiones más centrales de la galaxia. Actualice el tamaño de los marcadores a $0.5$, de manera que sea más suave la visualización de la distribución de estrellas. Plotee además las estrellas vistas en el plano $[x, y]$, $[x, z]$, $[y, z]$.
#
# Recuerde agregar los labels en cada eje.
#
# Póngase creativo con los gráficos, defina tamaños de la figura, agregue colores, defina los tamaños de los labels, etc.

# %%
# Grafique vista en plano [x, y] aquí
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()
ax.plot(df_galaxia["x[m]"], df_galaxia["y[m]"], '*', markersize=0.5)
ax.set_xlim(-0.5E19, 0.5E19)
ax.set_ylim(-0.75E19, 0.5E19)
ax.set_title("Estrellas vistas en el plano [x,y]", fontsize=13)
ax.set_xlabel("Posiciones de las estrellas en el eje x [m]", fontsize=13)
ax.set_ylabel("Posiciones de las estrellas en el eje y [m]", fontsize=13)
# Out:
# Text(0, 0.5, 'Posiciones de las estrellas en el eje y [m]')

# %%
# Grafique vista en plano [x, z] aquí
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()
ax.plot(df_galaxia["x[m]"], df_galaxia["z[m]"], '*', markersize=0.5, color='lightgreen')
ax.set_xlim(-2.5E18, 2.5E18)
ax.set_ylim(-0.55E18, 0.5E18)
ax.set_title("Estrellas vistas en el plano [x,z]", fontsize=13)
ax.set_xlabel("Posiciones de las estrellas en el eje x [m]", fontsize=13)
ax.set_ylabel("Posiciones de las estrellas en el eje z [m]", fontsize=13)
# Out:
# Text(0, 0.5, 'Posiciones de las estrellas en el eje z [m]')

# %%
# Grafique vista en plano [y, z] aquí
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot()
ax.plot(df_galaxia["y[m]"], df_galaxia["z[m]"], '*', markersize=0.5, color='purple')
ax.set_xlim(-2.5E18, 2.5E18)
ax.set_ylim(-0.5E18, 0.5E18)
ax.set_title("Estrellas vistas en el plano [y,z]", fontsize=13)
ax.set_xlabel("Posiciones de las estrellas en el eje y [m]", fontsize=13)
ax.set_ylabel("Posiciones de las estrellas en el eje z [m]", fontsize=13)
# Out:
# Text(0, 0.5, 'Posiciones de las estrellas en el eje z [m]')

# %% [markdown]
# #### Distribuciones
#
# Calcule la distancia $r$ y ángulo $\theta$ de cada una de las estrellas y añada estos valores a las columnas del dataframe original. Donde
#
# $r = \sqrt{x^2 + y^2 + z^2}$
#
# $θ = \arctan(y/x)$

# %%
def calcular_r(x, y, z):
  return np.sqrt(x**2 + y**2 + z**2)
def calcular_theta(y, x):
  return np.arctan(y/x)

for (_, series) in df_galaxia.iterrows():
  x = series["x[m]"]
  y = series["y[m]"]
  z = series["z[m]"]
  r = calcular_r(x, y, z)
  theta = calcular_theta(y, x)
  df_galaxia.loc[df_galaxia["key"] == series["key"], "r[m]"] = r
  df_galaxia.loc[df_galaxia["key"] == series["key"], "theta[rad]"] = theta
df_galaxia
# Out:
#                         key          x[m]          y[m]          z[m]  \
# 0       2536799254509432540  9.016510e+17  4.745163e+17  3.009401e+16
# 1      16568176108934293527 -9.545587e+16 -2.795457e+17 -2.217165e+16
# 2        212848180443948653  4.908724e+17 -1.870607e+18  9.142949e+15
# 3        584293945272726282 -8.367689e+17 -2.974291e+17 -4.054180e+15
# 4      15485527814176396751  2.343487e+16  2.799849e+17 -2.554723e+16
# ...                     ...           ...           ...           ...
# 40095   8972477052627890130 -5.257426e+17 -2.160534e+19 -1.687303e+18
# 40096   3695764516254316728  1.963205e+17  1.183779e+18  4.895338e+17
# 40097  17617397667571159511 -4.528748e+18 -4.665755e+18  3.232435e+18
# 40098  16130134547917784508  2.947325e+18 -3.515739e+15  1.659993e+18
# 40099  11941135087396799780 -2.541212e+18  2.372081e+18  1.282449e+18
#
#             vx[m/s]       vy[m/s]       vz[m/s]          r[m]  theta[rad]
# 0     -1.625572e+06  2.845114e+06 -3.486599e+04  1.019336e+18    0.484446
# 1      1.855060e+06 -1.920465e+06 -2.893263e+05  2.962249e+17    1.241743
# 2      3.380713e+06  7.971010e+05  4.905219e+04  1.933962e+18   -1.314169
# 3      6.618865e+05 -3.375086e+06  2.686391e+05  8.880668e+17    0.341521
# 4     -2.484394e+06 -1.171416e+05 -5.705734e+05  2.821230e+17    1.487291
# ...             ...           ...           ...           ...         ...
# 40095 -9.137532e+05 -6.192531e+05 -1.911085e+04  2.167750e+19    1.546467
# 40096  5.597525e+05 -4.871850e+06  1.731664e+06  1.295962e+18    1.406450
# 40097  2.553710e+06 -2.112712e+06 -2.013541e+06  7.261368e+18    0.800298
# 40098  1.339880e+06 -1.200858e+06 -1.979899e+06  3.382649e+18   -0.001193
# 40099  2.736939e+06  4.692433e+06  1.187456e+06  3.705294e+18   -0.750989
#
# [40100 rows x 9 columns]

# %% [markdown]
# Finalmente, visualize la distribución de $r$ y $\theta$ con un histograma. Esto se puede contruir desde cero con matplotlib, sin embargo pandas simplifica hacer análisis como estos, permitiendo rápidamente hacer diferentes análisis estadísticos. El siguiente codigo muestra como se puede plotear un histograma a partir de un dataframe de Pandas:
#
#
# ```
# dataframe.plot.hist(y=column_name, bins=n_bins)
# ```
#
# Utilice una escala logarítmica en el eje vertical del histograma de la coordenada radial ($r$). Use la cantidad de bins que considere que representen bien la distribución.

# %%
df_galaxia.plot.hist(y="r[m]", bins=20, log=True)
df_galaxia.plot.hist(y="theta[rad]", bins=1000)
# Out:
# <Axes: ylabel='Frequency'>
